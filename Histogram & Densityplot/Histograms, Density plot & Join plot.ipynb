# %%
#importing Dependancies
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
#Reading Dataset
df=pd.read_csv("iris.csv")
df
# Out:
#       Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 0      1                5.1               3.5                1.4
# 1      2                4.9               3.0                1.4
# 2      3                4.7               3.2                1.3
# 3      4                4.6               3.1                1.5
# 4      5                5.0               3.6                1.4
# ..   ...                ...               ...                ...
# 145  146                6.7               3.0                5.2
# 146  147                6.3               2.5                5.0
# 147  148                6.5               3.0                5.2
# 148  149                6.2               3.4                5.4
# 149  150                5.9               3.0                5.1
#
#      Petal Width (cm)         Species
# 0                 0.2     Iris-setosa
# 1                 0.2     Iris-setosa
# 2                 0.2     Iris-setosa
# ...

# %%
#plotting Histogram for Petal Length
plt.figure(figsize=(16,8))
sns.histplot(data=df,x='Petal Length (cm)',kde=True,color='navy')
# Out:
# <AxesSubplot:xlabel='Petal Length (cm)', ylabel='Count'>

# %%
#KDE plot
plt.figure(figsize=(16,8))
sns.kdeplot(data=df,x='Petal Length (cm)',shade=True,color='g')
# Out:
# <AxesSubplot:xlabel='Petal Length (cm)', ylabel='Density'>

# %%
# 2D KDE plot
sns.jointplot(data=df,x='Petal Length (cm)', y='Sepal Width (cm)', kind="kde",height=8,color='firebrick')

# %%
df_setosa=pd.read_csv("iris_setosa.csv")
df_versicolor=pd.read_csv("iris_versicolor.csv")
df_virginica=pd.read_csv("iris_virginica.csv")

# %%
# Histograms for each species

plt.figure(figsize=(16,10))

sns.distplot(x=df_setosa['Petal Length (cm)'],label='Setosa',kde=False,color='chocolate')

sns.distplot(x=df_versicolor['Petal Length (cm)'],label='versicolor',kde=False,color='lawngreen')

sns.distplot(x=df_virginica['Petal Length (cm)'],label='virginica',kde=False,color='deeppink')

plt.legend(ncol=3)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# KDE plots for each species
plt.figure(figsize=(16,10))

sns.kdeplot(x=df_setosa['Petal Length (cm)'],label='Setosa',color='chocolate',shade=True)

sns.kdeplot(x=df_versicolor['Petal Length (cm)'],label='versicolor',color='lawngreen',shade=True)

sns.kdeplot(x=df_virginica['Petal Length (cm)'],label='virginica',color='deeppink',shade=True)

plt.legend(ncol=3)

# %% [markdown]
# ### Practice Dataset

# %%
df_b=pd.read_csv('cancer_b.csv',index_col='Id')
df_b.head()
# Out:
#          Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 8510426          B         13.540           14.36             87.46
# 8510653          B         13.080           15.71             85.63
# 8510824          B          9.504           12.44             60.34
# 854941           B         13.030           18.42             82.61
# 85713702         B          8.196           16.84             51.71
#
#           Area (mean)  Smoothness (mean)  Compactness (mean)  \
# Id
# 8510426         566.3            0.09779             0.08129
# 8510653         520.0            0.10750             0.12700
# 8510824         273.9            0.10240             0.06492
# 854941          523.8            0.08983             0.03766
# 85713702        201.9            0.08600             0.05943
#
#           Concavity (mean)  Concave points (mean)  Symmetry (mean)  ...  \
# Id                                                                  ...
# ...

# %%
df_m=pd.read_csv('cancer_m.csv',index_col='Id')
df_m.head()
# Out:
#          Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 842302           M          17.99           10.38            122.80
# 842517           M          20.57           17.77            132.90
# 84300903         M          19.69           21.25            130.00
# 84348301         M          11.42           20.38             77.58
# 84358402         M          20.29           14.34            135.10
#
#           Area (mean)  Smoothness (mean)  Compactness (mean)  \
# Id
# 842302         1001.0            0.11840             0.27760
# 842517         1326.0            0.08474             0.07864
# 84300903       1203.0            0.10960             0.15990
# 84348301        386.1            0.14250             0.28390
# 84358402       1297.0            0.10030             0.13280
#
#           Concavity (mean)  Concave points (mean)  Symmetry (mean)  ...  \
# Id                                                                  ...
# ...

# %%
#In the first five rows of the data for benign tumors, what is the largest value for 'Perimeter (mean)'?
max_perim = 87.46


#What is the value for 'Radius (mean)' for the tumor with Id 842517?
mean_radius = 20.57

# %%
# Histograms for benign and maligant tumors
plt.figure(figsize=(16,10))

sns.distplot(x=df_b['Area (mean)'],kde=False) 
sns.distplot(x=df_m['Area (mean)'],kde=False)
# Out:
# <AxesSubplot:>

# %%
# KDE plots for benign and malignant tumors
plt.figure(figsize=(16,10))
sns.kdeplot(data=df_b,x='Radius (worst)',shade=True,color='g') 
sns.kdeplot(data=df_m,x='Radius (worst)',shade=True,color='r')
# Out:
# <AxesSubplot:xlabel='Radius (worst)', ylabel='Density'>
